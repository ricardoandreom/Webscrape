# %%
#!pip install bs4

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
#scrape a single game shots. We will allow users to enter a base url
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match

#Output:
#Please enter the match id:  16754
# Out:
# Please enter the match id: 16754

# %%
#Use requests to get the webpage and BeautifulSoup to parse the page
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
#get only the shotsData
strings = scripts[1].string

# %%
strings

# %%
# strip unnecessary symbols and get only JSON data 
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

data
# Out:
# {'h': [{'id': '477932',
#    'minute': '2',
#    'result': 'MissedShots',
#    'X': '0.955999984741211',
#    'Y': '0.605999984741211',
#    'xG': '0.0635618269443512',
#    'player': 'Fernandinho',
#    'h_a': 'h',
#    'player_id': '614',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Cross'},
#   {'id': '477933',
#    'minute': '4',
#    'result': 'BlockedShot',
#    'X': '0.855',
#    'Y': '0.649000015258789',
#    'xG': '0.06113557890057564',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Pass'},
#   {'id': '477934',
#    'minute': '23',
#    'result': 'BlockedShot',
#    'X': '0.8569999694824219',
#    'Y': '0.43099998474121093',
#    'xG': '0.09564501792192459',
#    'player': 'Phil Foden',
#    'h_a': 'h',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '477935',
#    'minute': '27',
#    'result': 'BlockedShot',
#    'X': '0.8919999694824219',
#    'Y': '0.74',
#    'xG': '0.032729268074035645',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'John Stones',
#    'lastAction': 'Chipped'},
#   {'id': '477936',
#    'minute': '30',
#    'result': 'MissedShots',
#    'X': '0.845999984741211',
#    'Y': '0.6140000152587891',
#    'xG': '0.06224839761853218',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'BallRecovery'},
#   {'id': '477940',
#    'minute': '43',
#    'result': 'BlockedShot',
#    'X': '0.9680000305175781',
#    'Y': '0.34700000762939454',
#    'xG': '0.05484689027070999',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'None'},
#   {'id': '477941',
#    'minute': '44',
#    'result': 'BlockedShot',
#    'X': '0.75',
#    'Y': '0.7069999694824218',
#    'xG': '0.01756650023162365',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '477942',
#    'minute': '46',
#    'result': 'BlockedShot',
#    'X': '0.7859999847412109',
#    'Y': '0.610999984741211',
#    'xG': '0.025742145255208015',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '477943',
#    'minute': '47',
#    'result': 'SavedShot',
#    'X': '0.9180000305175782',
#    'Y': '0.5640000152587891',
#    'xG': '0.06785253435373306',
#    'player': 'Aymeric Laporte',
#    'h_a': 'h',
#    'player_id': '2498',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Riyad Mahrez',
#    'lastAction': 'Cross'},
#   {'id': '477944',
#    'minute': '47',
#    'result': 'MissedShots',
#    'X': '0.8980000305175782',
#    'Y': '0.425',
#    'xG': '0.050726842135190964',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '477945',
#    'minute': '49',
#    'result': 'BlockedShot',
#    'X': '0.9319999694824219',
#    'Y': '0.5120000076293946',
#    'xG': '0.1357671171426773',
#    'player': 'Riyad Mahrez',
#    'h_a': 'h',
#    'player_id': '750',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Oleksandr Zinchenko',
#    'lastAction': 'Pass'},
#   {'id': '477946',
#    'minute': '49',
#    'result': 'MissedShots',
#    'X': '0.9640000152587891',
#    'Y': '0.5320000076293945',
#    'xG': '0.5863218307495117',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Cross'},
#   {'id': '477947',
#    'minute': '50',
#    'result': 'MissedShots',
#    'X': '0.769000015258789',
#    'Y': '0.34',
#    'xG': '0.020437704399228096',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Riyad Mahrez',
#    'lastAction': 'Pass'},
#   {'id': '477948',
#    'minute': '53',
#    'result': 'BlockedShot',
#    'X': '0.9230000305175782',
#    'Y': '0.48400001525878905',
#    'xG': '0.05040643364191055',
#    'player': 'John Stones',
#    'h_a': 'h',
#    'player_id': '586',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Aerial'},
#   {'id': '477949',
#    'minute': '66',
#    'result': 'BlockedShot',
#    'X': '0.919000015258789',
#    'Y': '0.6430000305175781',
#    'xG': '0.055538300424814224',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Cross'},
#   {'id': '477950',
#    'minute': '67',
#    'result': 'MissedShots',
#    'X': '0.7919999694824219',
#    'Y': '0.735',
#    'xG': '0.05326961353421211',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '477952',
#    'minute': '70',
#    'result': 'MissedShots',
#    'X': '0.845999984741211',
#    'Y': '0.5579999923706055',
#    'xG': '0.09440555423498154',
#    'player': 'Phil Foden',
#    'h_a': 'h',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Rodri',
#    'lastAction': 'TakeOn'},
#   {'id': '477953',
#    'minute': '72',
#    'result': 'MissedShots',
#    'X': '0.8580000305175781',
#    'Y': '0.5220000076293946',
#    'xG': '0.13904286921024323',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Pass'},
#   {'id': '477954',
#    'minute': '73',
#    'result': 'MissedShots',
#    'X': '0.9280000305175782',
#    'Y': '0.5420000076293945',
#    'xG': '0.061578407883644104',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Aerial'},
#   {'id': '477955',
#    'minute': '75',
#    'result': 'Goal',
#    'X': '0.9669999694824218',
#    'Y': '0.555',
#    'xG': '0.509554922580719',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Cross'},
#   {'id': '477956',
#    'minute': '76',
#    'result': 'SavedShot',
#    'X': '0.9219999694824219',
#    'Y': '0.545',
#    'xG': '0.08914723247289658',
#    'player': 'John Stones',
#    'h_a': 'h',
#    'player_id': '586',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Cross'},
#   {'id': '477957',
#    'minute': '77',
#    'result': 'Goal',
#    'X': '0.8169999694824219',
#    'Y': '0.5820000076293945',
#    'xG': '0.04535672441124916',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Oleksandr Zinchenko',
#    'lastAction': 'Pass'},
#   {'id': '477958',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.8230000305175781',
#    'Y': '0.34900001525878904',
#    'xG': '0.04231446236371994',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Chipped'},
#   {'id': '477959',
#    'minute': '80',
#    'result': 'MissedShots',
#    'X': '0.9030000305175782',
#    'Y': '0.27399999618530274',
#    'xG': '0.04056774452328682',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '477960',
#    'minute': '80',
#    'result': 'Goal',
#    'X': '0.980999984741211',
#    'Y': '0.5359999847412109',
#    'xG': '0.9017161726951599',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Rebound'}],
#  'a': [{'id': '477937',
#    'minute': '36',
#    'result': 'Goal',
#    'X': '0.925',
#    'Y': '0.45299999237060545',
#    'xG': '0.06013134494423866',
#    'player': 'Matthew Cash',
#    'h_a': 'a',
#    'player_id': '8864',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Lucas Digne',
#    'lastAction': 'Aerial'},
#   {'id': '477938',
#    'minute': '40',
#    'result': 'BlockedShot',
#    'X': '0.8680000305175781',
#    'Y': '0.36400001525878906',
#    'xG': '0.08686976879835129',
#    'player': 'Ollie Watkins',
#    'h_a': 'a',
#    'player_id': '8865',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Philippe Coutinho',
#    'lastAction': 'Pass'},
#   {'id': '477939',
#    'minute': '41',
#    'result': 'MissedShots',
#    'X': '0.7319999694824219',
#    'Y': '0.4159999847412109',
#    'xG': '0.0209199208766222',
#    'player': 'Philippe Coutinho',
#    'h_a': 'a',
#    'player_id': '488',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'None'},
#   {'id': '477951',
#    'minute': '68',
#    'result': 'Goal',
#    'X': '0.855999984741211',
#    'Y': '0.6229999923706054',
#    'xG': '0.07991967350244522',
#    'player': 'Philippe Coutinho',
#    'h_a': 'a',
#    'player_id': '488',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'HeadPass'}]}

# %%
x = []
y = []
xG = []
result = []
situation = []
player_assisted = []
lastAction = []
shotType = []
minute = []
team = []
id = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'situation':
            situation.append(data_home[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_home[index][key])
        if key == 'shotType':
            shotType.append(data_home[index][key])
        if key == 'lastAction':
            lastAction.append(data_home[index][key])
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'match_id':
            id.append(data_home[index][key]) 


for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'situation':
            situation.append(data_away[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_away[index][key])
        if key == 'shotType':
            shotType.append(data_away[index][key])
        if key == 'lastAction':
            lastAction.append(data_away[index][key])
        if key == 'minute':
            minute.append(data_away[index][key])
        if key == 'match_id':
            id.append(data_away[index][key])

# %%
col_names = ['match id','x','y','xG','result','situation','team','player assisted','shot type','last action','minute']
df = pd.DataFrame([id,x,y,xG,result,situation,team,player_assisted,shotType,lastAction,minute],index=col_names)
df = df.T

df.head()
# Out:
#   match id                   x                    y                    xG  \
# 0    16754   0.955999984741211    0.605999984741211    0.0635618269443512
# 1    16754               0.855    0.649000015258789   0.06113557890057564
# 2    16754  0.8569999694824219  0.43099998474121093   0.09564501792192459
# 3    16754  0.8919999694824219                 0.74  0.032729268074035645
# 4    16754   0.845999984741211   0.6140000152587891   0.06224839761853218
#
#         result situation             team  player assisted  shot type  \
# 0  MissedShots  SetPiece  Manchester City  Kevin De Bruyne       Head
# 1  BlockedShot  OpenPlay  Manchester City       Phil Foden  RightFoot
# 2  BlockedShot  OpenPlay  Manchester City    Gabriel Jesus  RightFoot
# 3  BlockedShot  OpenPlay  Manchester City      John Stones   LeftFoot
# 4  MissedShots  OpenPlay  Manchester City       Phil Foden  RightFoot
#
#     last action minute
# 0         Cross      2
# 1          Pass      4
# 2          Pass     23
# 3       Chipped     27
# 4  BallRecovery     30

# %% [markdown]
# **Scrape em 2 clicks a partir daqui**

# %%
#!pip install bs4
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
#scrape a single game shots. We will allow users to enter a base url
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

strings = scripts[1].string

ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

x = []
y = []
xG = []
result = []
situation = []
player_assisted = []
lastAction = []
shotType = []
minute = []
team = []
id = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'situation':
            situation.append(data_home[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_home[index][key])
        if key == 'shotType':
            shotType.append(data_home[index][key])
        if key == 'lastAction':
            lastAction.append(data_home[index][key])
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'match_id':
            id.append(data_home[index][key]) 


for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'situation':
            situation.append(data_away[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_away[index][key])
        if key == 'shotType':
            shotType.append(data_away[index][key])
        if key == 'lastAction':
            lastAction.append(data_away[index][key])
        if key == 'minute':
            minute.append(data_away[index][key])
        if key == 'match_id':
            id.append(data_away[index][key])  

col_names = ['match id','x','y','xG','result','situation','team','player assisted','shot type','last action','minute']
df = pd.DataFrame([id,x,y,xG,result,situation,team,player_assisted,shotType,lastAction,minute],index=col_names)
df = df.T

df.head()
#df.to_excel('under'.xlsx)
